# %% [markdown]
# python scripts/train_pakistan.py --config configs/pakistan_train.yaml

# %% [markdown]
# python scripts/evaluate_pakistan.py --config configs/pakistan_train.yaml --checkpoint outputs/pakistan_baseline/best.pt

# %% [markdown]
# python scripts/infer_test_split.py --config configs/pakistan_train.yaml --checkpoint outputs/non_physics/best.pt --output-dir outputs/non_physics/test_infer --max-samples 5 --start-index 5

# %% [markdown]
# python scripts/visualize_tif_pair.py --gt data/pakistan/flood_maps/969000.tif --pred outputs/non_physics/test_infer/pred/test_0802_t_1209600_pred.tif --output outputs/non_physics/test_infer/vis/test_0001_pair.png
